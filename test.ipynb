# %%
#pip install langchain==0.1.6
#pip install sqlalchemy==2.0.1

#pip install langchain_aws streamlit streamlit_chat

import boto3  # AWS SDK for Python(integrate AWS services for Python)
from langchain.prompts import PromptTemplate
from langchain_community.embeddings import BedrockEmbeddings # To access Bedrock's Titan Text embedding model.BedrockEmbeddings uses AWS Bedrock API to generate embeddings for given text for saving to vectordb 
from langchain_community.vectorstores.faiss import FAISS
from langchain_aws import ChatBedrock
from langchain.chains import ConversationalRetrievalChain  # Langchain fuction to create chatbot that can remember past interactions
import streamlit as st
from streamlit_chat import message

# %%
## Add Contexual compressor
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import LLMChainExtractor

# %%
pip show sqlalchemy
pip show langchain_aws
pip list | grep langchain
# Out:
#   Cell In[2], line 1
#     pip show sqlalchemy
#         ^
# SyntaxError: invalid syntax

# %%
def pretty_print_docs(docs):
  print(f"\n{'-'* 100}\n".join([F"Document{i+1}:\n\n" + d.page_content for i,d in enumerate(docs)]))

# %%
DB_FAISS_PATH = 'vectorstore/db_faiss'

# Initialise boto session
boto_session = boto3.Session()
aws_region = boto_session.region_name
# runtime client to call Bedrock models
br_runtime = boto_session.client(service_name='bedrock-runtime', region_name=aws_region)

#Loading the model
def load_llm():
    llm = ChatBedrock(
                      model_id='anthropic.claude-3-sonnet-20240229-v1:0',
                      model_kwargs={"temperature": 0.12, "max_tokens": 2000},
                      client=br_runtime
        )
    return llm


custom_prompt_template = """
    You are a Data Discovery AI assistance created by Fannie Mae.Your goal is to help users with data related questions. 
    You should maintain a friendly customer service tone.

    Here are some important rules for the interaction:
    - Use English language for answering questions.
    - Always stay in charater
    - Look across all datasets before answering the question.
    - Provide top 20 records on questions with multiple records
    - If someone asks irrelevant question, say, I am Data Discovery AI assistant and can't help with above question.
    - Be specific and don't add extra information in the response that is not asked for.

    How do you respond to user's question?

    Think about your answer first before you respond.You will look around all datasets and will use the context to answer the user's question.
    If you don't know the answer, just say that you don't know, don't try to make up an answer.
    
    Context: {context}
    Chat History: {chat_history}
    Question: {question}

    Only return the helpful answer below and nothing else.
    Helpful answer:
"""


def set_custom_prompt():
    """
    Prompt template for QA retrieval for each vectorstore
    """
    prompt = PromptTemplate(template=custom_prompt_template,
                            input_variables=['context', 'question', 'chat_history'])
    return prompt


embeddings = BedrockEmbeddings(model_id='amazon.titan-embed-text-v1', client=br_runtime)
#db = FAISS.load_local(DB_FAISS_PATH, embeddings, allow_dangerous_deserialization=True)
#llm = load_llm()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 55
#      51     return prompt
#      54 embeddings = BedrockEmbeddings(model_id='amazon.titan-embed-text-v1', client=br_runtime)
# ---> 55 db = FAISS.load_local(DB_FAISS_PATH, embeddings, allow_dangerous_deserialization=True)
#      56 llm = load_llm()
#      57 prompt = set_custom_prompt()
#
# File /opt/conda/lib/python3.10/site-packages/langchain_community/vectorstores/faiss.py:1117, in FAISS.load_local(cls, folder_path, embeddings, index_name, **kwargs)
#    1115 with open(path / "{index_name}.pkl".format(index_name=index_name), "rb") as f:
#    1116     docstore, index_to_docstore_id = pickle.load(f)
# -> 1117 return cls(embeddings, index, docstore, index_to_docstore_id, **kwargs)
#
# TypeError: FAISS.__init__() got an unexpected keyword argument 'allow_dangerous_deserialization'

# %%
db = FAISS.load_local(DB_FAISS_PATH, embeddings)

# %%
retriever = db.as_retriever(search_kwargs={'k':30})
docs = retriever.get_relevant_documents(query="list all tables") 
#pretty_print_docs(docs)
# Out:
# Document1:
#
# ﻿Dataset Reg ID: DSET000111
# Dataset Name: Participant Demographic Data
# Dataset Description: This table provides comparison of demographic group prevalence in Orgs. Volunteer population to that of greater US population
# Dataset Type: EDL
# Cloud ID: BPO2233
# Data Source System: Demographics
# Dataset Layer: S3
# Dataset Classification Type: External
# Topic: US Census Bureau
# Topic Category: Demographic Analysis
# Business Owner: toolika@gmail.com
# Technical POC: abc@gmail.com
# S3 Bucket/AWS Service: s3-us-east-1
# Structured Data: Structured
# Cloud Database Name: cloud_participant_demographic
# Table Name: ameri_part_demo_grp
# File Format: PARQUET
# Refresh Type: Snapshot
# Refresh Frequency: Yearly
# Dataset Data Retention Period: 6 Years
# ----------------------------------------------------------------------------------------------------
# Document2:
#
# ﻿Attribute Reg ID:
# Physical Attribute Name: curr_list_strt_date
# Logical Attribute Name: curr list strt date
# Description: The agreed upon date, between a property seller and a broker, authorizing the broker to begin the process to procure a buyer or tenant for the property seller’s real property.
# Dataset Reg ID: DSET000114
# Sequence Number: 67
# DataType: DATE
# Length Precision:
# Scale:
# Format:
# ----------------------------------------------------------------------------------------------------
# Document3:
#
# ﻿Attribute Reg ID:
# Physical Attribute Name: orig_list_strt_date
# Logical Attribute Name: orig list strt date
# Description: The agreed upon date, between a property seller and a broker, authorizing the broker to begin the process to procure a buyer or tenant for the property seller’s real property.
# Dataset Reg ID: DSET000114
# Sequence Number: 65
# DataType: DATE
# Length Precision:
# Scale:
# Format:
# ----------------------------------------------------------------------------------------------------
# Document4:
#
# ﻿Attribute Reg ID:
# Physical Attribute Name: alt_dlq_reso_cnt
# Logical Attribute Name: alt dlq reso cnt
# Description: The total number of Alternative Delinquency Resolutions as reported by the servicer for a specific loan.
# Dataset Reg ID: DSET000114
# Sequence Number: 107
# DataType: NUMERIC
# Length Precision:
# Scale:
# Format:
# ----------------------------------------------------------------------------------------------------
# Document5:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: curr_list_strt_date
# Reported Attribute Name: curr_list_strt_date
# Sequence Field Index: 67
# Profiled Data Type: Date
# Reported Data Type: Date
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document6:
#
# ﻿Dataset Reg ID: DSET000113
# Dataset Name: Loan Performance Data
# Dataset Description: This table provides monthly loan-level credit performance data through the Performance Cutoff Date up to property disposition is reported for all loans included in the performance files
# Dataset Type: EDL
# Cloud ID: BPO2235
# Data Source System: Loan Performance
# Dataset Layer: S3
# Dataset Classification Type: External
# Topic: Freddie Loan Population
# Topic Category: Loan Performance Data
# Business Owner: toolika@gmail.com
# Technical POC: ghi@gmail.com
# S3 Bucket/AWS Service: s3-us-east-1
# Structured Data: Structured
# Cloud Database Name: freddie_performance_data
# Table Name: fre_performance_data
# File Format: PARQUET
# Refresh Type: Snapshot
# Refresh Frequency: Quarterly
# Dataset Data Retention Period: Not defined
# ----------------------------------------------------------------------------------------------------
# Document7:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: curr_list_price
# Reported Attribute Name: curr_list_price
# Sequence Field Index: 68
# Profiled Data Type: Numeric (22,4)
# Reported Data Type: Numeric (22,4)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document8:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: ref_pool_id
# Reported Attribute Name: ref_pool_id
# Sequence Field Index: 1
# Profiled Data Type: STRING
# Reported Data Type: Varchar(150)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document9:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: orig_list_strt_date
# Reported Attribute Name: orig_list_strt_date
# Sequence Field Index: 65
# Profiled Data Type: Date
# Reported Data Type: Date
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document10:
#
# ﻿Attribute Reg ID:
# Physical Attribute Name: orig_list_pric
# Logical Attribute Name: orig list pric
# Description: The initial price at which a real property is offered for sale by the property seller.
# Dataset Reg ID: DSET000114
# Sequence Number: 66
# DataType: NUMERIC
# Length Precision:
# Scale:
# Format:
# ----------------------------------------------------------------------------------------------------
# Document11:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: alt_dlq_reso_cnt
# Reported Attribute Name: alt_dlq_reso_cnt
# Sequence Field Index: 107
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 165
# Min Value: 1
# Max Value: 2
# Null Count: 9335
# Density: 0.017368421
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 165
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document12:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: orig_list_pric
# Reported Attribute Name: orig_list_pric
# Sequence Field Index: 66
# Profiled Data Type: Numeric (22,4)
# Reported Data Type: Numeric (22,4)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document13:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: master_servicer
# Reported Attribute Name: master_servicer
# Sequence Field Index: 7
# Profiled Data Type: STRING
# Reported Data Type: Varchar(150)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document14:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: ARM_prod_type
# Reported Attribute Name: ARM_prod_type
# Sequence Field Index: 89
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document15:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: curr_unschedule_prinicipal
# Reported Attribute Name: curr_unschedule_prinicipal
# Sequence Field Index: 50
# Profiled Data Type: Numeric (22,4)
# Reported Data Type: Numeric (22,4)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document16:
#
# ﻿Attribute Reg ID:
# Physical Attribute Name: pay_hist
# Logical Attribute Name: pay hist
# Description: The coded string of values that describes the payment performance of the loan over the most recent 24 months.  The most recent month is located to the right.
# Dataset Reg ID: DSET000114
# Sequence Number: 41
# DataType: ALPHA-NUMERIC
# Length Precision:
# Scale:
# Format:
# ----------------------------------------------------------------------------------------------------
# Document17:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: pay_deferral_mod_ind
# Reported Attribute Name: pay_deferral_mod_ind
# Sequence Field Index: 109
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 9499
# Min Value: 7
# Max Value: 7
# Null Count: 1
# Density: 0.999894737
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 9499
# Cardinality: 1
# Selectivity: 0.000105274
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document18:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: deal_name
# Reported Attribute Name: deal_name
# Sequence Field Index: 104
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 1
# Min Value: N
# Max Value: N
# Null Count: 9499
# Density: 0.000105263
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 1
# Cardinality: 1
# Selectivity: 1.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document19:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: ARM_balloon_ind
# Reported Attribute Name: ARM_balloon_ind
# Sequence Field Index: 100
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document20:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: zb_code_change_date
# Reported Attribute Name: zb_code_change_date
# Sequence Field Index: 82
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 1
# Min Value: N
# Max Value: N
# Null Count: 9499
# Density: 0.000105263
# Date Time Count: 0
# Numeric Count: 0
# String Count: 1
# Boolean Count: 1
# Cardinality: 1
# Selectivity: 1.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document21:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: pay_hist
# Reported Attribute Name: pay_hist
# Sequence Field Index: 41
# Profiled Data Type: STRING
# Reported Data Type: varchar(150)
# Value Count: 8991
# Min Value: 0
# Max Value: XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX01
# Null Count: 509
# Density: 0.946421053
# Date Time Count: 0
# Numeric Count: 0
# String Count: 8991
# Boolean Count: 0
# Cardinality: 623
# Selectivity: 0.069291514
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document22:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: relo_mrtg_ind
# Reported Attribute Name: relo_mrtg_ind
# Sequence Field Index: 81
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 9499
# Min Value: N
# Max Value: Y
# Null Count: 1
# Density: 0.999894737
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 9499
# Cardinality: 2
# Selectivity: 0.000210548
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document23:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: amrt_type
# Reported Attribute Name: amrt_type
# Sequence Field Index: 35
# Profiled Data Type: STRING
# Reported Data Type: varchar(10)
# Value Count: 9500
# Min Value: 25
# Max Value: FRM
# Null Count: 0
# Density: 1.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 9500
# Boolean Count: 0
# Cardinality: 2
# Selectivity: 0.000210526
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document24:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: curr_schedule_prinicipal
# Reported Attribute Name: curr_schedule_prinicipal
# Sequence Field Index: 48
# Profiled Data Type: Numeric (22,4)
# Reported Data Type: Numeric (22,4)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document25:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: tax_cost
# Reported Attribute Name: tax_cost
# Sequence Field Index: 58
# Profiled Data Type: Numeric (22,4)
# Reported Data Type: Numeric (22,4)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document26:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: mort_ins_cancel_indicator
# Reported Attribute Name: mort_ins_cancel_indicator
# Sequence Field Index: 43
# Profiled Data Type: STRING
# Reported Data Type: varchar(150)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document27:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: repurchase_mkwh_proc_flag
# Reported Attribute Name: repurchase_mkwh_proc_flag
# Sequence Field Index: 105
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 102
# Min Value: N
# Max Value: Y
# Null Count: 9398
# Density: 0.010736842
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 102
# Cardinality: 2
# Selectivity: 0.019607843
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document28:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: amrt_mnths
# Reported Attribute Name: amrt_mnths
# Sequence Field Index: 39
# Profiled Data Type: integer
# Reported Data Type: integer
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document29:
#
# ﻿Dataset Reg ID: DSET000112
# Dataset Name: Loan Origination Data
# Dataset Description: This table provides information on origination characteristics of all mortgages purchased or guaranteed by Freddie Mac with origination dates between January 1, 1999 and the Origination Cutoff Date
# Dataset Type: EDL
# Cloud ID: BPO2234
# Data Source System: Loan Origination
# Dataset Layer: S3
# Dataset Classification Type: External
# Topic: Freddie Loan Population
# Topic Category: Loan Origination Data
# Business Owner: toolika@gmail.com
# Technical POC: def@gmail.com
# S3 Bucket/AWS Service: s3-us-east-1
# Structured Data: Structured
# Cloud Database Name: freddie_origination_data
# Table Name: fre_origination_data
# File Format: PARQUET
# Refresh Type: Snapshot
# Refresh Frequency: Quarterly
# Dataset Data Retention Period: Not defined
# ----------------------------------------------------------------------------------------------------
# Document30:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: frst_hb_indicator
# Reported Attribute Name: frst_hb_indicator
# Sequence Field Index: 26
# Profiled Data Type: STRING
# Reported Data Type: varchar(10)
# Value Count: 9500
# Min Value: 722
# Max Value: Y
# Null Count: 0
# Density: 1.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 9500
# Boolean Count: 0
# Cardinality: 1
# Selectivity: 0.000105263
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:

# %%
llm = load_llm()
#making the compressor
compressor = LLMChainExtractor.from_llm(llm=llm)
#compressor retriver = base retriever + compressor
compression_retriever = ContextualCompressionRetriever(base_retriever=retriever,
                                                       base_compressor=compressor)

# %%
#default compressor prompt
#print(compressor.llm_chain.prompt.template)
# Out:
# Given the following question and context, extract any part of the context *AS IS* that is relevant to answer the question. If none of the context is relevant return NO_OUTPUT.
#
# Remember, *DO NOT* edit the extracted parts of the context.
#
# > Question: {question}
# > Context:
# >>>
# {context}
# >>>
# Extracted relevant parts:

# %%
from langchain.retrievers.document_compressors import EmbeddingsFilter

embdeddings_filter = EmbeddingsFilter(embeddings=embeddings)
compression_retriever_filter = ContextualCompressionRetriever(base_retriever=retriever,
                                                       base_compressor=embdeddings_filter)
#
compressed_docs = compression_retriever_filter.get_relevant_documents(query="List all tables")
#pretty_print_docs(compressed_docs)
# Out:
# Document1:
#
# ﻿Dataset Reg ID: DSET000113
# Dataset Name: Loan Performance Data
# Dataset Description: This table provides monthly loan-level credit performance data through the Performance Cutoff Date up to property disposition is reported for all loans included in the performance files
# Dataset Type: EDL
# Cloud ID: BPO2235
# Data Source System: Loan Performance
# Dataset Layer: S3
# Dataset Classification Type: External
# Topic: Freddie Loan Population
# Topic Category: Loan Performance Data
# Business Owner: toolika@gmail.com
# Technical POC: ghi@gmail.com
# S3 Bucket/AWS Service: s3-us-east-1
# Structured Data: Structured
# Cloud Database Name: freddie_performance_data
# Table Name: fre_performance_data
# File Format: PARQUET
# Refresh Type: Snapshot
# Refresh Frequency: Quarterly
# Dataset Data Retention Period: Not defined
# ----------------------------------------------------------------------------------------------------
# Document2:
#
# ﻿Dataset Reg ID: DSET000111
# Dataset Name: Participant Demographic Data
# Dataset Description: This table provides comparison of demographic group prevalence in Orgs. Volunteer population to that of greater US population
# Dataset Type: EDL
# Cloud ID: BPO2233
# Data Source System: Demographics
# Dataset Layer: S3
# Dataset Classification Type: External
# Topic: US Census Bureau
# Topic Category: Demographic Analysis
# Business Owner: toolika@gmail.com
# Technical POC: abc@gmail.com
# S3 Bucket/AWS Service: s3-us-east-1
# Structured Data: Structured
# Cloud Database Name: cloud_participant_demographic
# Table Name: ameri_part_demo_grp
# File Format: PARQUET
# Refresh Type: Snapshot
# Refresh Frequency: Yearly
# Dataset Data Retention Period: 6 Years
# ----------------------------------------------------------------------------------------------------
# Document3:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: curr_list_strt_date
# Reported Attribute Name: curr_list_strt_date
# Sequence Field Index: 67
# Profiled Data Type: Date
# Reported Data Type: Date
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document4:
#
# ﻿Attribute Reg ID:
# Physical Attribute Name: alt_dlq_reso_cnt
# Logical Attribute Name: alt dlq reso cnt
# Description: The total number of Alternative Delinquency Resolutions as reported by the servicer for a specific loan.
# Dataset Reg ID: DSET000114
# Sequence Number: 107
# DataType: NUMERIC
# Length Precision:
# Scale:
# Format:
# ----------------------------------------------------------------------------------------------------
# Document5:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: orig_list_strt_date
# Reported Attribute Name: orig_list_strt_date
# Sequence Field Index: 65
# Profiled Data Type: Date
# Reported Data Type: Date
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document6:
#
# ﻿Dataset Reg ID: DSET000112
# Dataset Name: Loan Origination Data
# Dataset Description: This table provides information on origination characteristics of all mortgages purchased or guaranteed by Freddie Mac with origination dates between January 1, 1999 and the Origination Cutoff Date
# Dataset Type: EDL
# Cloud ID: BPO2234
# Data Source System: Loan Origination
# Dataset Layer: S3
# Dataset Classification Type: External
# Topic: Freddie Loan Population
# Topic Category: Loan Origination Data
# Business Owner: toolika@gmail.com
# Technical POC: def@gmail.com
# S3 Bucket/AWS Service: s3-us-east-1
# Structured Data: Structured
# Cloud Database Name: freddie_origination_data
# Table Name: fre_origination_data
# File Format: PARQUET
# Refresh Type: Snapshot
# Refresh Frequency: Quarterly
# Dataset Data Retention Period: Not defined
# ----------------------------------------------------------------------------------------------------
# Document7:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: curr_list_price
# Reported Attribute Name: curr_list_price
# Sequence Field Index: 68
# Profiled Data Type: Numeric (22,4)
# Reported Data Type: Numeric (22,4)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document8:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: alt_dlq_reso_cnt
# Reported Attribute Name: alt_dlq_reso_cnt
# Sequence Field Index: 107
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 165
# Min Value: 1
# Max Value: 2
# Null Count: 9335
# Density: 0.017368421
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 165
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document9:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: orig_list_pric
# Reported Attribute Name: orig_list_pric
# Sequence Field Index: 66
# Profiled Data Type: Numeric (22,4)
# Reported Data Type: Numeric (22,4)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document10:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: relo_mrtg_ind
# Reported Attribute Name: relo_mrtg_ind
# Sequence Field Index: 81
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 9499
# Min Value: N
# Max Value: Y
# Null Count: 1
# Density: 0.999894737
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 9499
# Cardinality: 2
# Selectivity: 0.000210548
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document11:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: ARM_prod_type
# Reported Attribute Name: ARM_prod_type
# Sequence Field Index: 89
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document12:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: ref_pool_id
# Reported Attribute Name: ref_pool_id
# Sequence Field Index: 1
# Profiled Data Type: STRING
# Reported Data Type: Varchar(150)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document13:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: zb_code_change_date
# Reported Attribute Name: zb_code_change_date
# Sequence Field Index: 82
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 1
# Min Value: N
# Max Value: N
# Null Count: 9499
# Density: 0.000105263
# Date Time Count: 0
# Numeric Count: 0
# String Count: 1
# Boolean Count: 1
# Cardinality: 1
# Selectivity: 1.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document14:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: deal_name
# Reported Attribute Name: deal_name
# Sequence Field Index: 104
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 1
# Min Value: N
# Max Value: N
# Null Count: 9499
# Density: 0.000105263
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 1
# Cardinality: 1
# Selectivity: 1.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document15:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: ARM_balloon_ind
# Reported Attribute Name: ARM_balloon_ind
# Sequence Field Index: 100
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document16:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: pay_hist
# Reported Attribute Name: pay_hist
# Sequence Field Index: 41
# Profiled Data Type: STRING
# Reported Data Type: varchar(150)
# Value Count: 8991
# Min Value: 0
# Max Value: XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX01
# Null Count: 509
# Density: 0.946421053
# Date Time Count: 0
# Numeric Count: 0
# String Count: 8991
# Boolean Count: 0
# Cardinality: 623
# Selectivity: 0.069291514
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document17:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: pay_deferral_mod_ind
# Reported Attribute Name: pay_deferral_mod_ind
# Sequence Field Index: 109
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 9499
# Min Value: 7
# Max Value: 7
# Null Count: 1
# Density: 0.999894737
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 9499
# Cardinality: 1
# Selectivity: 0.000105274
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document18:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: frst_hb_indicator
# Reported Attribute Name: frst_hb_indicator
# Sequence Field Index: 26
# Profiled Data Type: STRING
# Reported Data Type: varchar(10)
# Value Count: 9500
# Min Value: 722
# Max Value: Y
# Null Count: 0
# Density: 1.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 9500
# Boolean Count: 0
# Cardinality: 1
# Selectivity: 0.000105263
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document19:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: int_ubp
# Reported Attribute Name: int_ubp
# Sequence Field Index: 110
# Profiled Data Type: BOOLEAN
# Reported Data Type: Varchar(1)
# Value Count: 1
# Min Value: 7
# Max Value: 7
# Null Count: 9499
# Density: 0.000105263
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 1
# Cardinality: 1
# Selectivity: 1.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:
# ----------------------------------------------------------------------------------------------------
# Document20:
#
# Dataset Reg ID: DSET000114
# Dataset Name: Single-Family Historical Loan Performance
# Dataset Schema Version: 1
# Virtual Folder Name: Single_Family_S3
# Profiled Status: Profiled
# Reported Format: csv
# Datasource URI: s3-us-east-2
# Profiled Attribute Name: master_servicer
# Reported Attribute Name: master_servicer
# Sequence Field Index: 7
# Profiled Data Type: STRING
# Reported Data Type: Varchar(150)
# Value Count: 0
# Min Value:
# Max Value:
# Null Count: 9500
# Density: 0.0
# Date Time Count: 0
# Numeric Count: 0
# String Count: 0
# Boolean Count: 0
# Cardinality: 0
# Selectivity: 0.0
# Field Level Tag(s):
# Resource Tag(s):
# Total Tag Count:

# %%
prompt = set_custom_prompt()
from langchain.chains import RetrievalQA
qa = RetrievalQA.from_chain_type(llm=llm,
                                 chain_type="stuff",
                                 retriever=compression_retriever_filter,
                                 verbose=True)
#Ask Question
qa("List all tables")
# Out:
# > Entering new RetrievalQA chain...
#
# > Finished chain.
# {'query': 'List all tables',
#  'result': 'Based on the context provided, here are the table names mentioned:\n\n1. fre_performance_data\n2. ameri_part_demo_grp\n3. fre_origination_data'}

# %%
"""
qa_chain = ConversationalRetrievalChain.from_llm(llm=llm,
                                                 chain_type='stuff',
                                                 retriever=compression_retriever_filter,
                                                 verbose=True,
                                                 combine_docs_chain_kwargs={'prompt': prompt},
                                                 return_source_documents=True,
                                                 output_key='answer'
                                                )
                                                """
